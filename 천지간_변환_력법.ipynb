# %% [markdown]
# <a href="https://colab.research.google.com/github/Neccrow/Lunar-Calander/blob/main/%EC%B2%9C%EC%A7%80%EA%B0%84_%EB%B3%80%ED%99%98_%EB%A0%A5%EB%B2%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
## 파이썬에서 sys 모드 불러오기

q = input('서력에서 천간력을 입력하시려면 "w", 천간력에서 서력으로 입력하시려면 "e" 를 입력하시오!\n')
## 질문형 코드 입력하기

if q == 'w': ## 만약 q 값이 w 라면 
    wy = int(input('서력 년도를 입력하세요.\n'))
    ## 입력 되는 값 숫자로 변환
    rmy = {1 : "甲子", 2 : "乙丑", 3 : "丙寅",4 : "丁卯", 5 : "戊辰", 6 : "己巳", 7 : "庚午", 8 : "辛未", 9 : "壬申", 10 : "癸酉", 11 : "甲戌", 12 : "乙亥", 13 : "丙子", 14 : "丁丑", 15 : "戊寅", 16 : "己卯", 17 : "庚辰", 18 : "辛巳", 19 : "壬午", 20 : "癸未", 21 : "甲申", 22 : "乙酉", 23 : "丙戌", 24 : "丁亥", 25 : "戊子", 26 : "己丑", 27 : "庚寅", 28 : "辛卯", 29 : "壬辰", 30 : "癸巳", 31 : "甲午", 32 : "乙未", 33 : "丙申", 34 : "丁酉", 35 : "戊戌", 36 : "己亥", 37 : "庚子", 38 : "辛丑", 39 : "壬寅", 40 : "癸卯", 41 : "甲辰", 42 : "乙巳", 43 : "丙午", 44 : "丁未", 45 : "戊申", 46 : "己酉", 47 : "庚戌", 48 : "辛亥", 49 : "壬子", 50 : "癸丑", 51 : "甲寅", 52 : "乙卯", 53 : "丙辰", 54 : "丁巳", 55 : "戊午", 56 : "己未", 57 : "庚申", 58 : "辛酉", 59 : "壬戌", 0 : "癸亥"}
    ## rmy 딕셔너리 자료형 1번은 갑자 2번은 을축 등 
    cst = ['쥐','소', '호랑이', '토끼', '용', '뱀', '말', '양', '원숭이', '닭', '개','돼지']
    ## cst 리스트 자료형 cst 위치에 따라 숫자 번호로 메겨짐
    if wy > 0:
      ## 서력 년도가 기원후 일 경우 즉 양수 
      gj = (wy-3) % 60
      ## 서력 갑자 4년을 기준 공식 %를 이용하여 나누어진 숫자의 나머지를 구하는 방식
      print('서력에서 변환된 천간은 '+str(rmy[gj])+'년 입니다.\n')
      cs = (gj % 12)-1
      ## 중요 리스트 자료형은 제일 첫번째가 0이다. 즉 -1을 해줘야 제대로 값이 나옴 
      print('이 해는 '+str(cst[cs])+'띠 입니다.')
    elif wy < 0:
      ## 서력 년도 기원전 즉 음수
      gj = (wy-2) % 60
      ## 서력 갑자 -57년 기준 공식
      print('서력에서 변환된 천간은 '+str(rmy[gj])+'년 입니다.\n')
      cs = (gj % 12)-1
      print('이 해는 '+str(cst[cs])+'띠 입니다.')
    else:
      print('잘못된 값을 입력했습니다.')
      ## 기본 입력이 잘못될 경우 출력 값        
 
elif q == 'e': ## 만약 q 값이 e 라면
     gj = input('천간력을 입력하세요!(한자!)\n')
     ## 한자로 입력하는 천간력
     sty = int(input('기준 년도를 입력하세요!\n'))
     ## 60갑자 기준으로 돌아가기 때문에 기준 년도가 중요함 그것으로 서력 년간을 산출 할 수 있음
     chy = {"甲子" : 1, "乙丑" : 2, "丙寅" : 3, "丁卯" : 4, "戊辰" : 5, "己巳" : 6, "庚午" : 7, "辛未" : 8, "壬申" : 9, "癸酉" : 10, "甲戌" : 11, "乙亥" : 12, "丙子" : 13, "丁丑" : 14, "戊寅" : 15, "己卯" : 16, "庚辰" : 17, "辛巳" : 18, "壬午" : 19, "癸未" : 20,"甲申" : 21, "乙酉" : 22, "丙戌" : 23, "丁亥" : 24, "戊子" : 25, "己丑" : 26, "庚寅" : 27, "辛卯" : 28, "壬辰" : 29, "癸巳" : 30, "甲午" : 31, "乙未" : 32, "丙申" : 33, "丁酉" : 34, "戊戌" : 35, "己亥" : 36, "庚子" : 37, "辛丑" : 38, "壬寅" : 39, "癸卯" : 40, "甲辰" : 41, "乙巳" : 42, "丙午" : 43, "丁未" : 44, "戊申" : 45, "己酉" : 46, "庚戌" : 47, "辛亥" : 48, "壬子" : 49, "癸丑" : 50, "甲寅" : 51, "乙卯" : 52, "丙辰" : 53, "丁巳" : 54, "戊午" : 55, "己未" : 56, "庚申" : 57, "辛酉" : 58, "壬戌" : 59, "癸亥" : 0 }
     cst = ['쥐','소', '호랑이', '토끼', '용', '뱀', '말', '양', '원숭이', '닭', '개','돼지']
     if sty > 0: 
       ## 서력 년도가 양수일 경우 기원후일 경우
       sy = chy[gj]+3 ## 나머지 에서 서력 변환 역산 공식
       x = (sty // 60)
       ry = (x*60)+sy
       print('천간에서 변환된 서력년도 입니다.\n', ry)
       ly = (chy[gj] % 12)-1
       print('이 해는 '+str((cst[ly]))+'띠 입니다.\n')
     elif sty < 0:
       ## 서력 년도가 음수일 경우 기원전 경우
       sy = chy[gj]+2
       x = (sty // 60)
       ry = (x*60)+sy
       print('천간에서 변환된 서력년도 입니다.\n', ry)
       ly = (chy[gj] % 12)-1
       print('이 해는 '+str((cst[ly]))+'띠 입니다.\n')
     else:
       print('잘못된 입력값입니다.\n')   

else:
    print('잘못된 입력값 입니다!\n')
print("")
print("")
print("")
print("")
print("")
# Out:
# 서력에서 천간력을 입력하시려면 "w", 천간력에서 서력으로 입력하시려면 "e" 를 입력하시오!
# w
# 서력 년도를 입력하세요.
# 1977
# 서력에서 변환된 천간은 丁巳년 입니다.
#
# 이 해는 뱀띠 입니다.
